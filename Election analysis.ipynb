# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/G15/Desktop/joined_dashboard.csv")

# %%
df
# Out:
#     Constituency ID State ID           State Parliament Constituency  \
# 0             S0624      S06         Gujarat               SURAT(24)
# 1             S1226      S12  Madhya Pradesh              INDORE(26)
# 2              S032      S03           Assam               DHUBRI(2)
# 3             S1218      S12  Madhya Pradesh             VIDISHA(18)
# 4             S0625      S06         Gujarat             NAVSARI(25)
# ..              ...      ...             ...                     ...
# 538           S2611      S26    Chhattisgarh              KANKER(11)
# 539            S206      S20       Rajasthan          JAIPURRURAL(6)
# 540            S188      S18          Odisha               JAJPUR(8)
# 541           S1119      S11          Kerala            ATTINGAL(19)
# 542           S1327      S13     Maharashtra     MUMBAINORTHWEST(27)
#
#     Constituency Name (short)  Const No Constituency Name (long)  \
# 0                       Surat        24                    SURAT
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 543 entries, 0 to 542
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Constituency ID            543 non-null    object
#  1   State ID                   543 non-null    object
#  2   State                      543 non-null    object
#  3   Parliament Constituency    543 non-null    object
#  4   Constituency Name (short)  543 non-null    object
#  5   Const No                   543 non-null    int64
#  6   Constituency Name (long)   543 non-null    object
#  7   Status                     543 non-null    object
#  8   Winning Candidate          543 non-null    object
#  9   Winning Party              543 non-null    object
#  10  Winning Party ID           543 non-null    int64
#  11  Winner Votes               543 non-null    int64
#  12  Winner Vote Share          542 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Constituency ID              0
# State ID                     0
# State                        0
# Parliament Constituency      0
# Constituency Name (short)    0
# Const No                     0
# Constituency Name (long)     0
# Status                       0
# Winning Candidate            0
# Winning Party                0
# Winning Party ID             0
# Winner Votes                 0
# Winner Vote Share            1
# RunnerUp Candidate           1
# RunnerUp Party               1
# RunnerUp Votes               1
# Margin                       0
# Total Votes Polled           0
# Num Candidates               0
# Country                      0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#   Constituency ID State ID    State Parliament Constituency  \
# 0           S0624      S06  Gujarat               SURAT(24)
#
#   Constituency Name (short)  Const No Constituency Name (long)       Status  \
# 0                     Surat        24                    SURAT  Uncontested
#
#                               Winning Candidate                 Winning Party  \
# 0  MUKESHKUMAR CHANDRAKAANT DALAL (Uncontested)  Bharatiya Janata Party - BJP
#
#    Winning Party ID  Winner Votes  Winner Vote Share RunnerUp Candidate  \
# 0               369             0                NaN                NaN
#
#   RunnerUp Party  RunnerUp Votes  Margin  Total Votes Polled  Num Candidates  \
# 0            NaN             NaN       0                   0               1
#
#   Country
# 0   India

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Constituency ID              0
# State ID                     0
# State                        0
# Parliament Constituency      0
# Constituency Name (short)    0
# Const No                     0
# Constituency Name (long)     0
# Status                       0
# Winning Candidate            0
# Winning Party                0
# Winning Party ID             0
# Winner Votes                 0
# Winner Vote Share            0
# RunnerUp Candidate           0
# RunnerUp Party               0
# RunnerUp Votes               0
# Margin                       0
# Total Votes Polled           0
# Num Candidates               0
# Country                      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 542 entries, 1 to 542
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Constituency ID            542 non-null    object
#  1   State ID                   542 non-null    object
#  2   State                      542 non-null    object
#  3   Parliament Constituency    542 non-null    object
#  4   Constituency Name (short)  542 non-null    object
#  5   Const No                   542 non-null    int64
#  6   Constituency Name (long)   542 non-null    object
#  7   Status                     542 non-null    object
#  8   Winning Candidate          542 non-null    object
#  9   Winning Party              542 non-null    object
#  10  Winning Party ID           542 non-null    int64
#  11  Winner Votes               542 non-null    int64
#  12  Winner Vote Share          542 non-null    float64
# ...

# %%
import numpy as np

# %%
nums = df.select_dtypes(include=['object']).columns
df[nums] = df[nums].fillna("Unknown")
# Out:
# C:\Users\G15\AppData\Local\Temp\ipykernel_14156\108001526.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[nums] = df[nums].fillna("Unknown")

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#     Constituency ID State ID           State Parliament Constituency  \
# 1             S1226      S12  Madhya Pradesh              INDORE(26)
# 2              S032      S03           Assam               DHUBRI(2)
# 3             S1218      S12  Madhya Pradesh             VIDISHA(18)
# 4             S0625      S06         Gujarat             NAVSARI(25)
# 5              S066      S06         Gujarat          GANDHINAGAR(6)
# ..              ...      ...             ...                     ...
# 538           S2611      S26    Chhattisgarh              KANKER(11)
# 539            S206      S20       Rajasthan          JAIPURRURAL(6)
# 540            S188      S18          Odisha               JAJPUR(8)
# 541           S1119      S11          Kerala            ATTINGAL(19)
# 542           S1327      S13     Maharashtra     MUMBAINORTHWEST(27)
#
#     Constituency Name (short)  Const No Constituency Name (long)  \
# 1                      INDORE        26                   INDORE
# ...

# %%
df.to_csv("joined_dashboard_cleaned.csv",index = False)

# %% [markdown]
# After Cleaning and removing Duplicates and creating a new dataset named "joined_dashboard"

# %%
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df1 = pd.read_csv("C:/Users/G15/Desktop/joined_dashboard.csv")

# %%
df1
# Out:
#     Constituency ID State ID           State Parliament Constituency  \
# 0             S0624      S06         Gujarat               SURAT(24)
# 1             S1226      S12  Madhya Pradesh              INDORE(26)
# 2              S032      S03           Assam               DHUBRI(2)
# 3             S1218      S12  Madhya Pradesh             VIDISHA(18)
# 4             S0625      S06         Gujarat             NAVSARI(25)
# ..              ...      ...             ...                     ...
# 538           S2611      S26    Chhattisgarh              KANKER(11)
# 539            S206      S20       Rajasthan          JAIPURRURAL(6)
# 540            S188      S18          Odisha               JAJPUR(8)
# 541           S1119      S11          Kerala            ATTINGAL(19)
# 542           S1327      S13     Maharashtra     MUMBAINORTHWEST(27)
#
#     Constituency Name (short)  Const No Constituency Name (long)  \
# 0                       Surat        24                    SURAT
# ...

# %%
sns.boxplot(df1)
# Out:
# <Axes: >
